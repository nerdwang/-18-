# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
# 将数据分为训练集和测试集
X=np.load('mpnetemb.npy')
y=np.load('y.npy')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# 创建LightGBM分类器
clf = lgb.LGBMClassifier()

# 设置要搜索的参数范围
param_grid = {
    'num_leaves': [31, 50, 100],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 500]
}

# 创建GridSearchCV对象
grid = GridSearchCV(clf, param_grid, cv=3, scoring='accuracy')
grid.fit(X_train, y_train)

# 输出最佳参数
print("Best parameters found by grid search are:", grid.best_params_)

# 使用最佳参数的模型进行预测
y_pred = grid.predict(X_test)

# 评估模型
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# 打印分类报告
report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
# Out:
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073846 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087881 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.069378 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057202 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.060673 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053662 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056516 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.060105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057905 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053741 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054456 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.052512 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056492 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.071391 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053416 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051243 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073508 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057500 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056191 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057567 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055186 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058543 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058727 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055857 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.071549 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.060704 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056895 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.061711 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054646 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.052628 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.064753 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.076501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.079505 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053075 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055104 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.065708 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057818 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059798 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057857 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057826 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057532 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.063221 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087784 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.062226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054917 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053471 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058220 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090062 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057589 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054768 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059338 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.061069 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057416 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.061028 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053831 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053314 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.061271 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057992 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.063308 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.061136 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.063825 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057295 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057913 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055848 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056389 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23940, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474436 -> initscore=-0.102345
# [LightGBM] [Info] Start training from score -0.102345
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 11358, number of negative: 12583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058209 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 23941, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474416 -> initscore=-0.102424
# [LightGBM] [Info] Start training from score -0.102424
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 17037, number of negative: 18874
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074781 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 195840
# [LightGBM] [Info] Number of data points in the train set: 35911, number of used features: 768
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474423 -> initscore=-0.102398
# [LightGBM] [Info] Start training from score -0.102398
# Best parameters found by grid search are: {'learning_rate': 0.1, 'n_estimators': 500, 'num_leaves': 31}
# Accuracy: 0.9782802405881043
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4598
#            1       0.98      0.98      0.98      4380
#
#     accuracy                           0.98      8978
#    macro avg       0.98      0.98      0.98      8978
# weighted avg       0.98      0.98      0.98      8978

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 计算混淆矩阵
cm = confusion_matrix(y_test, y_pred)

# 创建热图
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", linewidths=2, linecolor="black")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

X=np.load('mpnetemb.npy')
y=np.load('y.npy')
# 将数据分为训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# 创建SVC模型
svc_model = SVC()

# 训练模型
svc_model.fit(X_train, y_train)

# 预测
y_pred = svc_model.predict(X_test)

# 评估模型
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# 打印分类报告
report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.9848518601024727
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4753
#            1       0.98      0.98      0.98      4225
#
#     accuracy                           0.98      8978
#    macro avg       0.98      0.98      0.98      8978
# weighted avg       0.98      0.98      0.98      8978

# %%
# 计算混淆矩阵
cm = confusion_matrix(y_test, y_pred)

# 创建热图
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", linewidths=2, linecolor="black")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
